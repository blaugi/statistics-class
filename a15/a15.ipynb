# %%
import random
import pandas as pd

# %%
prim_letra = ['q', 'w', 'x', 'z']
seg_letra = ['a', 'i', 'u']
ter_letra = ['c', 'f', 'p']
quar_letra = ['e', 'o']

random.seed(42)

# %%
def cria_lista_palavras(num_iter = 1):
    word_list = []
    for _ in range(num_iter):
        c1 = random.choice(prim_letra)
        c2 = random.choice(seg_letra)
        c3 = random.choice(ter_letra)
        c4 = random.choice(quar_letra)

        word = c1 + c2 + c3 + c4
        word_list.append(word)

    return word_list 


def calcula_porcentagem(word_list):
    dict_percent = {}
    for word in set(word_list):
        appearances = word_list.count(word)
        percent =  appearances / len(word_list) * 100
        dict_percent[word] = [appearances, round(percent, 2)] 
    return dict_percent

# %%
num_iters = [72, 216, 720, 2160, 7200, 72000]
words_of_interest = ['qace', 'qice', 'wace', 'wice', 'xace', 'zupo']

df = pd.DataFrame()

for num in num_iters:
    word_list = cria_lista_palavras(num)
    result = pd.DataFrame(calcula_porcentagem(word_list))

# %%
word_list = cria_lista_palavras(72)
result = pd.DataFrame(calcula_porcentagem(word_list)) 
result = result.T.rename(columns = {0 : "occurences", 1: "percentage" })
result['expected_percentage'] = 1.38
result = result.reset_index().apply()
# Out:
#    index  occurences  percentage  expected_percentage
# 0   wuce         1.0        1.39                 1.38
# 1   quco         1.0        1.39                 1.38
# 2   qace         1.0        1.39                 1.38
# 3   zupe         3.0        4.17                 1.38
# 4   xice         1.0        1.39                 1.38
# 5   zifo         1.0        1.39                 1.38
# 6   xufo         1.0        1.39                 1.38
# 7   qice         1.0        1.39                 1.38
# 8   xipo         1.0        1.39                 1.38
# 9   wico         1.0        1.39                 1.38
# 10  xaco         2.0        2.78                 1.38
# 11  wice         1.0        1.39                 1.38
# 12  xufe         1.0        1.39                 1.38
# 13  xape         2.0        2.78                 1.38
# 14  xico         1.0        1.39                 1.38
# 15  qufo         1.0        1.39                 1.38
# 16  xupo         1.0        1.39                 1.38
# 17  zafe         2.0        2.78                 1.38
# 18  wape         2.0        2.78                 1.38
# 19  zape         1.0        1.39                 1.38
# 20  zife         1.0        1.39                 1.38
# 21  zipo         1.0        1.39                 1.38
# 22  qapo         1.0        1.39                 1.38
# 23  qifo         1.0        1.39                 1.38
# 24  xapo         2.0        2.78                 1.38
# 25  qape         1.0        1.39                 1.38
# 26  qife         3.0        4.17                 1.38
# 27  qufe         4.0        5.56                 1.38
# 28  zufo         2.0        2.78                 1.38
# 29  xace         2.0        2.78                 1.38
# 30  wife         1.0        1.39                 1.38
# 31  wapo         1.0        1.39                 1.38
# 32  zapo         2.0        2.78                 1.38
# 33  wafo         1.0        1.39                 1.38
# 34  qipe         2.0        2.78                 1.38
# 35  zupo         1.0        1.39                 1.38
# 36  xafe         3.0        4.17                 1.38
# 37  qico         2.0        2.78                 1.38
# 38  xife         3.0        4.17                 1.38
# 39  zafo         1.0        1.39                 1.38
# 40  waco         4.0        5.56                 1.38
# 41  zaco         1.0        1.39                 1.38
# 42  wafe         1.0        1.39                 1.38
# 43  wipo         3.0        4.17                 1.38
# 44  xupe         1.0        1.39                 1.38
# 45  qipo         1.0        1.39                 1.38
